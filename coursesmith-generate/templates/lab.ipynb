# %% [markdown]
# # Lab: {{CHAPTER_TITLE}}
#
# > This notebook accompanies Chapter {{CHAPTER_NUM}} of {{BOOK_TITLE}}. It walks through the hands-on work step-by-step, but the point is for you to type and run the cells yourself, not just shift-enter through them.
#
# ## What you'll build
#
# {{LAB_OVERVIEW}}
#
# ## Prerequisites
#
# {{PREREQS}}
#
# ## Imports and setup

# %%
# {{IMPORTS_DESCRIPTION}}
{{IMPORTS_CODE}}

# %% [markdown]
# ## Step 1: {{STEP_1_TITLE}}
#
# {{STEP_1_EXPLANATION}}

# %%
{{STEP_1_CODE}}

# %% [markdown]
# **Try it**: {{STEP_1_TRY_IT_PROMPT}}
#
# **Common pitfalls**: {{STEP_1_PITFALLS}}

# %% [markdown]
# <!-- Repeat Step blocks for each progression in the chapter. End the notebook with a stretch-goals cell: -->
#
# ## Stretch goals
#
# {{STRETCH_GOALS}}
